# %% [markdown]
# | 슬라이드 | 슬라이드 제목 | 발표 대본 |
# |---|---|---|
# | 1 | 제목 | 안녕하세요. 저희는 **“뉴욕에서 임대업으로 부자되기, 쉽죠?”**라는 주제로 **에어비앤비 데이터**를 분석한 **10조**입니다. 이번 프로젝트에서는 **뉴욕 에어비앤비 데이터**를 활용하여 **어떤 지역과 숙소 전략이 실제로 수익성이 있는지**를 **데이터 기반**으로 분석했습니다. |
# | 2 | 목차 | 목차는 다음과 같이 구성하였습니다. |
# | 3 | 프로젝트 개요 | 먼저 **프로젝트 개요**입니다. 이번 프로젝트에서는 **에어비앤비 플랫폼**과 **뉴욕 단기 임대 규제 환경**을 함께 고려하여 **현실적인 임대 투자 전략**을 분석하는 것을 목표로 했습니다. |
# | 4 | 회사소개 및 배경 | 에어비앤비는 **“Belong Anywhere”**라는 철학을 가진 **세계 최대 숙박 공유 플랫폼**입니다. 하지만 뉴욕에서는 **Local Law 18 규제**가 시행되면서 **호스트 실거주 의무와 인원 제한** 등 **숙소 운영 방식**에 큰 변화가 생겼습니다. |
# | 5 | 목적 및 목표 | 이번 프로젝트의 목적은 크게 두 가지입니다. 첫째, **데이터 기반으로 뉴욕 숙소 시장의 수익 구조를 분석**하는 것입니다. 둘째, 분석 결과를 활용해 **투자자 유형별 매물 추천 전략**을 제시하는 것입니다. |
# | 6 | 데이터 전처리 | 다음은 **데이터 전처리 과정**입니다. 이 단계에서는 분석에 사용할 **데이터와 변수**를 정리하고 이후 **분석에 활용 가능한 데이터 구조**로 정리했습니다. |
# | 7 | 사용 변수 | 분석에는 **가격, 숙소 유형, 리뷰 수, 어메니티, 위치** 등 **에어비앤비 주요 변수**를 사용했습니다. 이 변수들을 기반으로 **숙소 수익성과 점유율**을 분석했습니다. |
# | 8 | 파생 변수 | 추가 분석을 위해 두 가지 **파생 변수**를 만들었습니다. 첫 번째는 **점유율(occupancy rate)**로 **숙박일수 ÷ 365일** 기준으로 계산했습니다. 두 번째는 **Property regulation type**으로 **뉴욕 규제 기준**에 따라 숙소를 분류했습니다. |
# | 9 | 데이터 필터링 | **데이터 신뢰성 확보**를 위해 여러 **필터링 작업**을 진행했습니다. **다수 숙소 운영 호스트 제거**, **minimum nights 기준 장기 숙박 분리**, 그리고 **가격 0 및 이상치 데이터 제거**를 수행했습니다. |
# | 10 | 분석 및 시뮬레이션 | 이제 **본격적인 분석 단계**입니다. **통계 분석**을 통해 **점유율 영향 요인**을 찾고, 그 결과를 기반으로 **투자 시뮬레이터와 매물 추천 분석**을 진행했습니다. |
# | 11 | 리뷰와 점유율 | 먼저 **리뷰 수와 점유율 관계**를 분석했습니다. **Spearman 상관 분석** 결과 **리뷰 수와 점유율 사이에 유의한 양의 상관관계**가 확인되었습니다. 즉 **리뷰가 많을수록 예약 가능성이 높아지는 경향**이 나타났습니다. |
# | 12 | 어메니티와 점유율 | 다음은 **어메니티 수와 점유율 관계**입니다. 분석 결과 **어메니티 수가 많을수록 점유율이 높아지는 경향**이 나타났습니다. 즉 **숙소 편의시설이 예약 선택에 중요한 요소**로 작용했습니다. |
# | 13 | 상관관계 분석 | **점유율과 주요 변수의 상관관계**를 종합적으로 분석했습니다. **리뷰 수와 어메니티 수는 양의 상관관계**, 반면 **가격은 약한 음의 상관관계**를 보였습니다. 즉 **가격이 높을수록 예약률이 약간 감소하는 경향**이 나타났습니다. |
# | 14 | 회귀 분석 | **회귀 분석 결과**도 유사한 경향을 보였습니다. **리뷰 수와 어메니티 수는 점유율 증가 요인**, 반면 **가격은 점유율 감소 요인**으로 나타났습니다. |
# | 15 | 추정 매출 | **리뷰 수 구간별 추정 매출**을 분석했습니다. 분석 결과 **리뷰가 많을수록 매출이 증가**했으며 특히 **리뷰 100개 이상 숙소에서 가장 높은 매출**이 나타났습니다. |
# | 16 | 어메니티 매출 | **어메니티별 매출 영향**도 분석했습니다. **Heating, Washer, Wifi**와 같은 **기본 편의시설**이 **매출과 가장 높은 연관성**을 보였습니다. |
# | 17 | 지역 분석 | **뉴욕 5개 자치구 시장 분석**을 진행했습니다. 분석 결과 **Manhattan과 Brooklyn**이 **가장 높은 시장 규모**를 보였으며 특히 **Manhattan이 가장 높은 매출**을 기록했습니다. |
# | 18 | 숙소 유형 | **숙소 유형별 수익 구조**를 비교했습니다. **Entire home 숙소가 가장 높은 수익**을 보였지만 **호텔형 숙소도 안정적인 수익 구조**를 보였습니다. |
# | 19 | 시뮬레이터 | 이러한 분석 결과를 기반으로 **투자 시뮬레이터**를 설계했습니다. 사용자가 **지역, 숙소 유형, 인원**을 입력하면 **예상 점유율과 수익**을 확인할 수 있도록 구성했습니다. |
# | 20 | 페르소나 | 다음으로 **투자자 페르소나 분석**을 진행했습니다. **프로부업러 김소희**, **부동산 투자자 이찬희**, **고수익 투자자 윤혜빈** 세 가지 유형을 기준으로 **매물 전략**을 분석했습니다. |
# | 21 | 매물 추천 1 | 첫 번째 페르소나는 **안정형 투자자 김소희**입니다. 우선 안전한 투자, 부업러 김소희 페르소나를 위해 경쟁 강도를 살펴봤습니다. 1인실과 2인실의 경쟁강도는 약 5.3배정도 1인실이 낮은 경향을 보이고 있습니다. 따라서 이 투자자를 위해서는 **리스크를 최소화하면서 안정적인 수익**을 추구하는 1인실을 제안해볼까? 라는 생각을 했습니다. |
# | 22 | 분석 결과 | **안정적인 수익을 추구하는** 페르소나이기에 운영 리스크도 분석해보았습니다. 분석 결과 2인실이 1인실보다 고정 관리비 부담은 높은것으로 확인되어, 월 순이익과 고정 관리비의 비율을 따져보고, **높은 경쟁 환경에서도 안정적인 점유율을 유지하는 숙소 전략**이 추천 매물로써 가장 적합하지 않을까란 생각을 했습니다. |
# | 23 | 추천 매물 | 시뮬레이터 실행 결과 **2인실은 레드오션**이지만 수익효율이 좋았고,  **1인실은 저수요 틈새시장**이라는 결과를 보였습니다. 즉, 각 매물의 장단점을 설명하여 두가지 매물을 추천해주었습니다. |
# | 24 | 매물 추천 2 | 두 번째 페르소나는 **부동산 투자자 이찬희**입니다. 이 투자자는 **높은 수익 가능성**을 중심으로 **추천 매물**을 요구하였습니다. |
# | 25 | 분석 결과 | Manhattan에 투자하길 원하여, 지역별 공급량과 점유을의 지표를 살펴보았습니다. 분석 결과 EDA에서는 **Manhattan 지역이 가장 높은 수익성**을 보였지만 동시에 **점유율은 가장 낮은 것**으로 나타났습니다. 즉, 경쟁이 아주 치열한 지역구라는 것을 확인할 수 있었습니다. |
# | 26 | 가격 경쟁 | 또한 대부분 숙소 가격이 **유사한 가격 구간에 집중**되면서 **가격 경쟁 구조**가 형성되는 것을 확인했습니다. |
# | 27 | 전략 | 따라서, 해당 페르소나의 요구에 맞추어 시뮬레이터를 돌려본 결과 **2인실보다 4인실 중심 전략**이 **수익 측면에서 더 유리**한 것으로 나타났습니다. |
# | 28 | 매물 추천 3 | 세 번째 페르소나는 **공간 기획자 윤혜빈**입니다. 이 투자자는 **높은 가격 전략을 통한 수익 극대화**를 목표로 합니다. 수용인원과 매물의 비중, 수익 효율 등을 살펴 보았을 때 **대형 숙소일수록 높은 수익 가능성**이 나타났습니다. |
# | 29 | 분석 결과 | 호스트의 니즈에 맞추어 시뮬레이터를 실행하였을 때, 앞서 말씀드린바와 같이 **대형 숙소일수록 높은 수익 가능성**이 나타났습니다. 5인이상인 숙소일 때 시장 포지션이 블루오션으로 나타나며, 이는 대형그룹의 수요를 타겟팅함으로써 수익 극대화 가능성이 높다는 점을 시사합니다. |
# | 30 | 결과 및 시사점 | 마지막으로, **프로젝트 결과와 시사점**입니다. 지금까지의 **분석 결과를 종합하여 투자 전략**을 정리했습니다. |
# | 31 | 전략 정리 | **안정형 투자자 → 리스크 최소화 전략**, **투자형 → 중간 규모(3~4인) 숙소 전략**, **고수익형 → 대형 숙소 전략**이 가장 적합했습니다. |
# | 32 | 인사이트 | 이번 프로젝트에서 얻은 **핵심 인사이트**는 네 가지입니다. **신뢰도와 편의성이 수익을 결정**, **맨해튼 2인실 중심 시장의 함정**, **리스크 최소화는 1인실 틈새시장**, **고수익 전략의 Key는 대형 숙소 운영**입니다. |
# | 33 | 마무리 | 슬라이드 마지막에 시뮬레이터 실행 영상 첨부하였습니다! 시간 관계상 발표는 마무리하겠습니다. 차후에 한번 보시는 것도 좋을 것 같습니다:) 이상으로 **뉴욕 에어비앤비 데이터를 활용한 임대 투자 전략 분석** 발표를 마치겠습니다. **감사합니다.** |
